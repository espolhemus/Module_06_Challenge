# %%
# Import the dependencies.
import pandas as pd
#import matplotlib.pyplot as plt
#%matplotlib notebook
import numpy as np
from citipy import citipy as citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=082ccd32fbf466c90e98e887c8b8fd7d

# %%
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_weather
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Based on an example found at https://www.geeksforgeeks.org/python-get-values-of-particular-key-in-list-of-dictionaries/
        city_description = [sub['description'] for sub in city_weather["weather"]]
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | half moon bay
# Processing Record 2 of Set 1 | sao joaquim
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | mataura
# Processing Record 5 of Set 1 | bejar
# Processing Record 6 of Set 1 | esperance
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | gujar khan
# Processing Record 9 of Set 1 | albany
# Processing Record 10 of Set 1 | puerto leguizamo
# Processing Record 11 of Set 1 | alofi
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | rikitea
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 16 of Set 1 | barrow
# Processing Record 17 of Set 1 | hobart
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | arlit
# Processing Record 20 of Set 1 | hasaki
# Processing Record 21 of Set 1 | tuatapere
# Processing Record 22 of Set 1 | sikea
# ...

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Half Moon Bay  37.4636 -122.4286     80.91        40           0
# 1       Sao Joaquim -28.2939  -49.9317     62.69        81          62
# 2         Upernavik  72.7868  -56.1549    -13.83        78         100
# 3           Mataura -46.1927  168.8643     53.47        60          95
# 4             Bejar  40.3864   -5.7634     46.58        71          47
# 5         Esperance -33.8667  121.9000     73.24        93         100
# 6         Busselton -33.6500  115.3333     58.08        91          43
# 7        Gujar Khan  33.2558   73.3026     48.63        39           6
# 8            Albany  42.6001  -73.9662     49.87        46          84
# 9  Puerto Leguizamo  -0.1934  -74.7819     83.68        67         100
#
#    Wind Speed Country Current Description
# 0        0.00      US         [clear sky]
# 1        4.50      BR     [broken clouds]
# 2       15.50      GL   [overcast clouds]
# ...

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0     Half Moon Bay      US  37.4636 -122.4286     80.91        40
# 1       Sao Joaquim      BR -28.2939  -49.9317     62.69        81
# 2         Upernavik      GL  72.7868  -56.1549    -13.83        78
# 3           Mataura      NZ -46.1927  168.8643     53.47        60
# 4             Bejar      ES  40.3864   -5.7634     46.58        71
# 5         Esperance      AU -33.8667  121.9000     73.24        93
# 6         Busselton      AU -33.6500  115.3333     58.08        91
# 7        Gujar Khan      PK  33.2558   73.3026     48.63        39
# 8            Albany      US  42.6001  -73.9662     49.87        46
# 9  Puerto Leguizamo      CO  -0.1934  -74.7819     83.68        67
#
#    Cloudiness  Wind Speed Current Description
# 0           0        0.00         [clear sky]
# 1          62        4.50     [broken clouds]
# 2         100       15.50   [overcast clouds]
# ...

# %%
# Convert Current Description from Float to STR and Remove [ and ] characters from output in Current Description
# Based on an example found at https://www.geeksforgeeks.org/how-to-convert-floats-to-strings-in-pandas-dataframe/
city_data_df["Current Description"] = city_data_df["Current Description"].astype(str)
city_data_df.dtypes

# Based on an example found at https://datatofish.com/replace-character-pandas-dataframe/
city_data_df["Current Description"] = city_data_df["Current Description"].str.replace(r"[", "" )
city_data_df["Current Description"] = city_data_df["Current Description"].str.replace(r"]", "")
city_data_df.head(10)
# Out:
# C:\Users\18177\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:7: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   import sys
# C:\Users\18177\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:8: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0     Half Moon Bay      US  37.4636 -122.4286     80.91        40
# 1       Sao Joaquim      BR -28.2939  -49.9317     62.69        81
# 2         Upernavik      GL  72.7868  -56.1549    -13.83        78
# 3           Mataura      NZ -46.1927  168.8643     53.47        60
# ...

# %%
# Remove ' character that was inserted during replacement of [] characters in Current Description
# Based on an example found at https://datatofish.com/replace-character-pandas-dataframe/
city_data_df["Current Description"] = city_data_df["Current Description"].str.replace(r"'", "")
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0     Half Moon Bay      US  37.4636 -122.4286     80.91        40
# 1       Sao Joaquim      BR -28.2939  -49.9317     62.69        81
# 2         Upernavik      GL  72.7868  -56.1549    -13.83        78
# 3           Mataura      NZ -46.1927  168.8643     53.47        60
# 4             Bejar      ES  40.3864   -5.7634     46.58        71
# 5         Esperance      AU -33.8667  121.9000     73.24        93
# 6         Busselton      AU -33.6500  115.3333     58.08        91
# 7        Gujar Khan      PK  33.2558   73.3026     48.63        39
# 8            Albany      US  42.6001  -73.9662     49.87        46
# 9  Puerto Leguizamo      CO  -0.1934  -74.7819     83.68        67
#
#    Cloudiness  Wind Speed Current Description
# 0           0        0.00           clear sky
# 1          62        4.50       broken clouds
# 2         100       15.50     overcast clouds
# ...

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
